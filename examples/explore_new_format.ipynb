# %% [markdown]
# # Brainstorming

# %% [markdown]
#  - Prediction comment format should stay the same for continuity
#
#  - Display number of late comments, on time comments summary when getting comments,
#  or a separate "get comments diagnostics" things
#
#  - Match serial number will be unique
#
#  - Metadata
#     - Serial number always goes up by one, even if a week is missed
#     - Matchweek is a field
#
#
#  CLI
#
#  predthread new target=<target-dir> team-name=<team-name> year=<year> fbref-squad-id=<fbref-squad-id>
#
#
# Project Directory Structure
#
# /<team-name>_<year>_<fbref-squad-id>

# %%
import predthread as pt
from api_keys import client_id, client_secret, user_agent
from datetime import datetime

# %%
reddit = pt.open_reddit(client_id, client_secret, user_agent)

# %%
url = "https://www.reddit.com/r/SaintsFC/comments/1b9d76d/prediction_thread_week_36_southampton_sunderland/"
time = datetime(2024, 3, 3, 9, 0)

# %%
reddit = pt.open_reddit(client_id, client_secret, user_agent)

# %%
thread = pt.open_thread(reddit, url)

# %%
pt.get_predictions(thread, comment_localtime_cutoff=time)
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
df = pt.get_standings(thread)
